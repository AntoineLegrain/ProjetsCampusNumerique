# %%
# Python ≥3.5 is required
import sys
assert sys.version_info >= (3, 5)

# Scikit-Learn ≥0.20 is required
import sklearn
assert sklearn.__version__ >= "0.20"

# Common imports
import numpy as np
import os

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

import pandas as pd

# %%
from scipy import spatial

import pysal
from pysal.cg.kdtree import KDTree

# %% [markdown]
# # Filling NaNs intellegently

# %% [markdown]
# We want to fill missing values with values from nearest tree (or the nearest tree taht have values).

# %% [markdown]
# # Creating new predictors

# %%
df_trees=pd.read_pickle('trees_first_clean.pkl')
df_trees.head()
# Out:
#        CODE CATEGORIE_DESC SOUS_CATEGORIE      SOUS_CATEGORIE_DESC  \
# 0  ESP32632          Arbre         ESP174  Arbre d'espaces ouverts
# 1  ESP32631          Arbre         ESP174  Arbre d'espaces ouverts
# 2  ESP32630          Arbre         ESP174  Arbre d'espaces ouverts
# 3  ESP32629          Arbre         ESP174  Arbre d'espaces ouverts
# 4  ESP32628          Arbre         ESP174  Arbre d'espaces ouverts
#
#                  CODE_PARENT_DESC  ADR_SECTEUR GENRE_BOTA          ESPECE  \
# 0  Prc Echangeurs Bastion St Roch            5       Acer  pseudoplatanus
# 1  Prc Echangeurs Bastion St Roch            5       Acer  pseudoplatanus
# 2  Prc Echangeurs Bastion St Roch            5       Acer  pseudoplatanus
# 3  Prc Echangeurs Bastion St Roch            5       Acer  pseudoplatanus
# 4  Prc Echangeurs Bastion St Roch            5       Acer  pseudoplatanus
#
#   VARIETE STADEDEDEVELOPPEMENT       COLLECTIVITE       LON        LAT  \
# 0     NaN         Arbre adulte  Ville de Grenoble  5.740727  45.190539
# 1     NaN         Arbre adulte  Ville de Grenoble  5.740748  45.190525
# 2     NaN         Arbre adulte  Ville de Grenoble  5.740697  45.190498
# 3     NaN         Arbre adulte  Ville de Grenoble  5.740675  45.190491
# 4     NaN         Arbre adulte  Ville de Grenoble  5.740702  45.190479
#
#    ANNEEDEPLANTATION
# 0             2001.0
# 1             2001.0
# 2             2001.0
# 3             2001.0
# 4             2001.0
