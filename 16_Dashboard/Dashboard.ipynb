# %%
import pandas as pd

# %%
Morticd10_1 = pd.read_csv('Data/Morticd10_part1')
# Out:
# /home/antoine/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
Morticd10_1.head()
# Out:
#    Country  Admin1  SubDiv  Year List Cause  Sex  Frmat  IM_Frmat  Deaths1  \
# 0     1400     NaN     NaN  2001  101  1000    1      7         8      332
# 1     1400     NaN     NaN  2001  101  1000    2      7         8      222
# 2     1400     NaN     NaN  2001  101  1001    1      7         8       24
# 3     1400     NaN     NaN  2001  101  1001    2      7         8       14
# 4     1400     NaN     NaN  2001  101  1002    1      7         8        0
#
#    ...  Deaths21  Deaths22  Deaths23  Deaths24  Deaths25  Deaths26  \
# 0  ...      95.0       NaN       NaN       NaN       NaN       0.0
# 1  ...     112.0       NaN       NaN       NaN       NaN       0.0
# 2  ...       5.0       NaN       NaN       NaN       NaN       0.0
# 3  ...       6.0       NaN       NaN       NaN       NaN       0.0
# 4  ...       0.0       NaN       NaN       NaN       NaN       0.0
#
#    IM_Deaths1  IM_Deaths2  IM_Deaths3  IM_Deaths4
# 0         8.0         NaN         NaN         NaN
# ...

# %%
Morticd10_1.columns
# Out:
# Index(['Country', 'Admin1', 'SubDiv', 'Year', 'List', 'Cause', 'Sex', 'Frmat',
#        'IM_Frmat', 'Deaths1', 'Deaths2', 'Deaths3', 'Deaths4', 'Deaths5',
#        'Deaths6', 'Deaths7', 'Deaths8', 'Deaths9', 'Deaths10', 'Deaths11',
#        'Deaths12', 'Deaths13', 'Deaths14', 'Deaths15', 'Deaths16', 'Deaths17',
#        'Deaths18', 'Deaths19', 'Deaths20', 'Deaths21', 'Deaths22', 'Deaths23',
#        'Deaths24', 'Deaths25', 'Deaths26', 'IM_Deaths1', 'IM_Deaths2',
#        'IM_Deaths3', 'IM_Deaths4'],
#       dtype='object')

# %%
Morticd10_1.describe()
# Out:
#             Country        Admin1  SubDiv          Year           Sex  \
# count  1.388106e+06  84173.000000     0.0  1.388106e+06  1.388106e+06
# mean   3.172264e+03    901.553610     NaN  2.000583e+03  1.524913e+00
# std    1.013357e+03      0.497121     NaN  2.493338e+00  7.972585e-01
# min    1.125000e+03    901.000000     NaN  1.988000e+03  1.000000e+00
# 25%    2.150000e+03    901.000000     NaN  1.999000e+03  1.000000e+00
# 50%    3.160000e+03    902.000000     NaN  2.001000e+03  1.000000e+00
# 75%    4.186000e+03    902.000000     NaN  2.003000e+03  2.000000e+00
# max    5.150000e+03    902.000000     NaN  2.004000e+03  9.000000e+00
#
#               Frmat      IM_Frmat       Deaths1       Deaths2       Deaths3  \
# count  1.388106e+06  1.388106e+06  1.388106e+06  1.387983e+06  1.387983e+06
# mean   1.958309e-01  3.060166e+00  1.777636e+02  4.695514e+00  6.455295e-01
# std    5.355721e-01  3.172315e+00  6.738730e+03  1.940484e+02  2.757854e+01
# ...

# %%
Morticd10_1[Morticd10_1.Country == 1400]
# Out:
#      Country  Admin1  SubDiv  Year List Cause  Sex  Frmat  IM_Frmat  Deaths1  \
# 0       1400     NaN     NaN  2001  101  1000    1      7         8      332
# 1       1400     NaN     NaN  2001  101  1000    2      7         8      222
# 2       1400     NaN     NaN  2001  101  1001    1      7         8       24
# 3       1400     NaN     NaN  2001  101  1001    2      7         8       14
# 4       1400     NaN     NaN  2001  101  1002    1      7         8        0
# ..       ...     ...     ...   ...  ...   ...  ...    ...       ...      ...
# 791     1400     NaN     NaN  2004  101  1101    2      7         8        0
# 792     1400     NaN     NaN  2004  101  1102    1      7         8        5
# 793     1400     NaN     NaN  2004  101  1102    2      7         8        1
# 794     1400     NaN     NaN  2004  101  1103    1      7         8        4
# 795     1400     NaN     NaN  2004  101  1103    2      7         8        1
#
# ...
