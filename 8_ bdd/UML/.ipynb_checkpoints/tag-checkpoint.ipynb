# %% [markdown]
# DROP TABLE IF EXISTS colleges;
# CREATE TABLE colleges (
#   c_name       TEXT,
#   state        TEXT,
#   enrollment   INT,
#   PRIMARY KEY  (c_name)
# );
#
# DROP TABLE IF EXISTS students;
# CREATE TABLE students (
#   s_id         INT,
#   s_name       TEXT,
#   gpa          REAL,
#   size_hs      INT,
#   PRIMARY KEY  (s_id)
# );
#
# DROP TABLE IF EXISTS applications;
# CREATE TABLE applications (
#   s_id         INT,
#   c_name       TEXT,
#   major        TEXT,
#   decision     TEXT,
#   PRIMARY KEY  (s_id, c_name, major),
#   FOREIGN KEY  (s_id) REFERENCES students(s_id),
#   FOREIGN KEY  (c_name) REFERENCES colleges(c_name)
# );

# %%
import pandas as pd

# %%
df_stops = pd.read_csv('SEM-GTFS/stops.txt')
df_agency=pd.read_csv('SEM-GTFS/agency.txt')
df_calendars_dates=pd.read_csv('SEM-GTFS/calendar_dates.txt')
df_fare_attributes=pd.read_csv('SEM-GTFS/fare_attributes.txt')
df_feed_info=pd.read_csv('SEM-GTFS/feed_info.txt')
df_routes=pd.read_csv('SEM-GTFS/routes.txt')
df_shapes=pd.read_csv('SEM-GTFS/shapes.txt')
df_stops=pd.read_csv('SEM-GTFS/stops.txt')
df_stop_times=pd.read_csv('SEM-GTFS/stop_times.txt')
df_trips=pd.read_csv('SEM-GTFS/trips.txt')

# %%
df_agency.head(1)
# Out:
#   agency_id          agency_name                   agency_url agency_timezone  \
# 0       SEM  Tag par Mobilites M  https://www.mobilites-m.fr/    Europe/Paris
#
#   agency_lang  agency_phone
# 0          FR     438703870

# %%
df_routes.head(1)
# Out:
#   agency_id  route_id route_short_name  \
# 0       SEM         1               C1
#
#                                route_long_name  route_type route_color  \
# 0  GRENOBLE Cité Jean Macé / MEYLAN Maupertuis           3      FDEA00
#
#   route_text_color
# 0           000000

# %%
df_stops.head(1)
# Out:
#   stop_id stop_code              stop_name  stop_lat  stop_lon  location_type  \
# 0    1133      1133  Vif, Z.A. des Speyres   45.0569   5.68184            NaN
#
#   parent_station  wheelchair_boarding
# 0          S3597                    0

# %%
df_stop_times.head(1)
# Out:
#    trip_id  stop_id arrival_time departure_time  stop_sequence  pickup_type
# 0  2225232     3923     08:10:00       08:10:00              1          NaN

# %%
df_trips.head(25)
# Out:
#     route_id  trip_id                       trip_headsign  \
# 0         51  2233989  GRENOBLE, PALAIS DE JUSTICE - GARE
# 1          1  2244970                  MEYLAN, MAUPERTUIS
# 2         50  2227148               GRENOBLE, VICTOR HUGO
# 3         26  2245420               GRENOBLE, GRAND'PLACE
# 4          1  2245228            GRENOBLE, CITE JEAN MACE
# 5         50  2237841               GRENOBLE, VICTOR HUGO
# 6         26  2240266          LE PONT-DE-CLAIX, L'ETOILE
# 7         46  2231981         FONTANIL-CORNILLON, PALLUEL
# 8         28  2231359                 SEYSSINS, LE PRISME
# 9         26  2245595          LE PONT-DE-CLAIX, L'ETOILE
# 10        52  2242406  SAINT-MARTIN-D'HERES, HENRI WALLON
# 11       107  2235913                       CLAIX, COSSEY
# 12        51  2233925      GIERES, UNIVERSITES - BIOLOGIE
# 13        53  2228737   SAINT-MARTIN-D'HERES, LES ALLOVES
# 14         4  2227913        MEYLAN, LYCEE DU GRESIVAUDAN
# 15        52  2249024  SAINT-MARTIN-D'HERES, HENRI WALLON
# 16        27  2233496           GIERES, PLAINE DES SPORTS
# 17         2  2230106                   CLAIX, PONT ROUGE
# 18         2  2228462             GRENOBLE, LOUISE MICHEL
# 19        46  2232443         FONTANIL-CORNILLON, PALLUEL
# 20         2  2226714             GRENOBLE, LOUISE MICHEL
# 21         1  2237272            GRENOBLE, CITE JEAN MACE
# 22        28  2231317                 SEYSSINS, LE PRISME
# 23        28  2248335                 SEYSSINS, LE PRISME
# 24       149  2238467  GIERES, UNIVERSITES - IUT - UFRAPS
#
#                  service_id  direction_id  shape_id  wheelchair_accessible  \
# 0         14-1-127$43-1-127             0  SEM_C5_1                      1
# 1                   42-1-31             0  SEM_C1_2                      1
# 2                  25-1-127             1  SEM_C4_2                      1
# 3                   32-1-31             0   SEM_A_3                      1
# 4                   39-1-31             1  SEM_C1_4                      1
# 5           38-1-31$40-1-31             1  SEM_C4_2                      1
# 6                   41-1-31             0   SEM_A_3                      1
# 7                  26-1-127             1   SEM_E_1                      1
# 8                    4-1-31             1   SEM_C_2                      1
# 9                   32-1-31             0   SEM_A_3                      1
# 10                 14-1-127             1  SEM_C6_1                      1
# 11                  37-1-31             0  SEM_48_1                      1
# 12        14-1-127$43-1-127             1  SEM_C5_2                      1
# 13        29-1-127$31-1-127             1  SEM_12_1                      1
# 14                  32-1-31             1  SEM_13_2                      1
# 15                 44-1-127             1  SEM_C6_1                      1
# 16                   8-1-31             0   SEM_B_1                      1
# 17                  32-1-31             0  SEM_C2_2                      1
# 18        29-1-127$31-1-127             1  SEM_C2_1                      1
# 19                   8-1-31             1   SEM_E_1                      1
# 20  38-1-31$40-1-31$41-1-31             1  SEM_C2_1                      1
# 21        14-1-127$43-1-127             1  SEM_C1_1                      1
# 22                   4-1-31             1   SEM_C_2                      1
# 23                 26-1-127             1   SEM_C_2                      1
# 24                  42-1-31             0  SEM_C7_1                      1
#
#     bikes_allowed
# 0               2
# 1               2
# 2               2
# 3               2
# 4               2
# 5               2
# 6               2
# 7               2
# 8               2
# 9               2
# 10              2
# 11              2
# 12              2
# 13              2
# 14              2
# 15              2
# 16              2
# 17              2
# 18              2
# 19              2
# 20              2
# 21              2
# 22              2
# 23              2
# 24              2

# %%
df_trips.loc[df_trips.trip_id==2236816]
# Out:
#     route_id  trip_id                  trip_headsign       service_id  \
# 51         5  2236816  LE PONT-DE-CLAIX, GENDARMERIE  39-1-31$42-1-31
#
#     direction_id shape_id  wheelchair_accessible  bikes_allowed
# 51             1      NaN                      1              2

# %%
df_trips.groupby(["route_id", "trip_id"]).count().drop_duplicates()
# Out:
#                   trip_headsign  service_id  direction_id  shape_id  \
# route_id trip_id
# 1        2225417              1           1             1         1
# 5        2236816              1           1             1         0
#
#                   wheelchair_accessible  bikes_allowed
# route_id trip_id
# 1        2225417                      1              1
# 5        2236816                      1              1

# %%
import sqlite3
def gen_insert_query(table_name:str, a_dict:dict) -> str:
    # https://sql.sh/cours/insert-into
    # INSERT INTO table-name (column-names)  VALUES (values) 
 
    insert_query_tpl = "INSERT INTO {} {} VALUES {} "
    keys, values = zip(*a_dict.items())
     
    compiled_query = insert_query_tpl.format(table_name, keys, values)
     
    return compiled_query

#Tentative de batch, mais impossible de commit plus de 50 fois (cf. transactions.).

# def gen_insert_file(filename,tablename,df): 
#     dict_row={}
#     df_c=df.dropna().copy()
#     i=0
#     conn = sqlite3.connect(filename)
#     for k in range(0,len(df_c)): 
        
#         c = conn.cursor()
#         for i in range(0,len(df_c.loc[k].values)):
#             dict_row[df_c.columns.values[i]]=df_c.loc[k].values[i]
#         query=gen_insert_query(tablename,dict_row)
#         print(query)
#         c.execute(query)
#         conn.commit()
#     conn.close()

def gen_insert_file(tablename:str,df): 
    dict_row={}
    df_c=df.fillna(value='None').copy()
    filename=tablename+"_insert.sql"
    print(filename)
    f= open(filename,"w+")
    f.write("BEGIN;")
    
#     insert_query_tpl = "INSERT INTO {} {} VALUES {} "
#     DROP TABLE IF EXISTS routes;
#     CREATE TABLE routes (
#         agency_id	STRING,
#         route_id	INT,
#         route_short_name	STRING,
#         route_long_name		STRING,
#         route_type		INT,
#         route_color		STRING,
#         route_text_color	INT,
#         FOREIGN KEY 	(agency_id) REFERENCES agency(agency_id),
#         PRIMARY KEY	(route_id)
#     );
    
    for k in range(0,len(df_c)):     
        for i in range(0,len(df_c.loc[k].values)):
            dict_row[df_c.columns.values[i]]=df_c.loc[k].values[i]
        query=gen_insert_query(tablename,dict_row)
        f.write(query)
        f.write(";\n")
    f.write("COMMIT;")
    f.close

# %%
gen_insert_file('trips',df_trips)
# Out:
# trips_insert.sql

# %%
str(df_trips_c.trip_id.dtype)
# Out:
# 'int64'

# %%
len(df_trips)
# Out:
# 18376
